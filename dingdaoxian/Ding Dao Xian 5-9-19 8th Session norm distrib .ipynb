# %% [markdown]
# ### Create random samples from a normal distribution using numpy
#
# ***numpy.random.normal(loc= ,scale= ,size= )***
# <br><br>Parameters:
# <br>a) <em>loc</em>: mean (center) of the distribution.
# <br>b) <em>scale</em>: standard deviation (spread or width) of the distribution.
# <br>c) <em>size</em>: output shape/ size of the samples.
# <br><br>Returns:
# <br> Drawn samples from the parameterized normal distribution.

# %% [markdown]
# **Example2.1**: Generate a random samples for normal distributions with the following properties:
# <br>a) size of samples=10000
# <br>b) mean=100
# <br>c) standard deviation=0.1

# %%
#SOLUTION:

#step 1: import nmupy libry
import numpy as np

#step 2: Assign the mean and standard deviation in a variable.
mean=100
sd=0.1
size=10000

#step 3: Create a random samples for normal distribution using numpy and put it in a list.
print(np.random.normal(mean,sd,size))#step 1: import nmupy libry
# Out:
# [ 99.94951884  99.99700474 100.00905463 ... 100.10888726  99.84029967
#   99.94039948]

# %% [markdown]
# ### Plot histogram for normal distribution using matplotlib
#
# ***matplotlib.pyplot.hist(data, bins, density=True, color)***
#
# <br>Parameters:
# <br>a) <em>data</em>: sample data for normal distribution.
# <br>b) <em>bins</em>: size of class interval. (It will create a list of bin edges)
# <br>c) <em>density</em>: booleans, if 'True', data is normalized.
# <br>d) <em>color</em>: bar color
# <br><br>Returns:
# <br> 1) Draw a histogram
# <br> 2) Return value of (array, bins, patches)
#
# <em>***We need this bins value to draw our normal distribution.</em>

# %% [markdown]
# **Example2.2**: Using the sample data from Example 2.1, draw a histogram for its normal distribution.

# %%
#SOLUTION:

#step 1: import matplotlib libry
import matplotlib.pyplot as plt

#step 2: Create a histogram for the random samples and set the number of data bins. Use appropriate number of bins. 
n, bins, patches =plt.hist(X,bins=50,density=True)

# %% [markdown]
# ### Probability density functions (pdf)
# Probability distributions are typically defined in terms of the probability density function. However, there are a number of probability functions used in applications.
#
# <br> For normal distribution, its probability density function (pdf) depends on its mean and standard deviation, where
# <br><img src="figure7.PNG">
#
# <br>Since for continuous distributions the probability at a single point is zero, this is often expressed in terms of an integral between two points.
#
# In python, we can use stats library to find the pdf for normal distribution:
# <br>***stats.norm.pdf(x, loc, scale)***
# <br><br>Parameters:
# <br>a) <em>x</em>: value from a distribution.
# <br>b) <em>loc</em>: mean (center) of the distribution.
# <br>c) <em>scale</em>: standard deviation (spread or width) of the distribution.
# <br><br>Returns:
# <br> Probability density function,pdf for a distribution.

# %% [markdown]
# **Example2.2**: Using the bins value from Example 2.2 , draw a graph for its ***probability density function(pdf)***.

# %%
#SOLUTION:

#step 1: import scipy libry
from scipy.stats import norm

#step 2: Find the pdf for each item in the bins and put it in a list.
pdf=[]
for i in bins:
    f=norm.pdf(i,mean,sd)
    pdf.append(f)

#step 3: Plot the graph for the pdf using matplotlib.
plt.plot(bins,pdf, linewidth=2, color='r')    

plt.xlabel('Data')
plt.ylabel('Probability')
plt.title('Pdf with mean=0, standard deviation=0.1')
plt.grid(True)
plt.show()

# %% [markdown]
# ### Commulative density functions (cdf)
# The comulative distribution function (cdf) is the probability that the variable takes a value less than or equal to x. <img src="figure19.PNG">
#
# <br>We know that the sum of all probabilities must equal 100%, therefore: <img src="figure20.PNG">
#
# In python, we can use stats libry to find the cdf for normal distribution:
# <br>***stats.norm.cdf(x, loc, scale)***
# <br><br>Parameters:
# <br>a) <em>x</em>: value from a distribution.
# <br>b) <em>loc</em>: mean (center) of the distribution.
# <br>c) <em>scale</em>: standard deviation (spread or width) of the distribution.
# <br><br>Returns:
# <br> Probability of less or equal than value of x.

# %% [markdown]
# **Example2.3**: Using the bins value from Example 2.2, draw a graph for its ***commulative density function (cdf)***.

# %%
#SOLUTION:

#step 1: Find the pdf for each item in the bins and put it in a list.
cdf=[]
for i in bins:
    f=norm.cdf(i,mean,sd)
    cdf.append(f)

#step 6: Plot the graph for the pdf using matplotlib.
plt.plot(bins,cdf, linewidth=2, color='g')    

plt.xlabel('Data')
plt.ylabel('Probability')
plt.title('Cdf with mean=100, standard deviation=0.1')
plt.grid(True)
plt.show()

# %% [markdown]
# ### Percent  point functions (ppf)
# The percent point function (ppf) is the inverse of the cumulative distribution function (cdf).
# For ppf, we start with the probability and compute the corresponding x for the cumulative distribution. <img src="figure21.PNG">
#
#
#
# In python, we can use stats libry to find the ppf for normal distribution:
# <br>***stats.norm.ppf(q, loc, scale)***
# <br><br>Parameters:
# <br>a) <em>q</em>: probability for value less than x.
# <br>b) <em>loc</em>: mean (center) of the distribution.
# <br>c) <em>scale</em>: standard deviation (spread or width) of the distribution.
# <br><br>Returns:
# <br>Value of x corresponding to the probability, q.

# %% [markdown]
# **Example4**: Based on the solution from Example 3 (for a and b only), use its probability to find the value of the corresponding x.
# (***HINT***: You should get back the same value of x from Example 3.)

# %%
#SOLUTION:

from scipy.stats import norm

mean=30
sd=4

#(a)
x=norm.ppf(0.894350226333, mean, sd)
print(x)

#(b)
x=norm.ppf(1-0.987775527345, mean, sd)
print(x)
# Out:
# 34.99999999999683
# 20.999999999994373

# %% [markdown]
# # Exercises

# %% [markdown]
# **TASK 2**: Generate a random samples for normal distributions with the following properties:
# <br>a) size of samples=5000
# <br>b) mean=150
# <br>c) standard deviation=30

# %%
#SOLUTION 2:
import numpy as np

mean=150
sd=30
size=5000

X=np.random.normal(mean,sd,size)
print(X)
print(max(X))

import matplotlib.pyplot as plt
import matplotlib.pyplot as plt
n, bins, patches =plt.hist(X,bins=50,density=False, color='purple')
print(n)
print(bins)
# Out:
# [138.82200294 183.88149204 130.5223823  ... 203.81327571 171.58294374
#  127.47231635]
# 245.3970583856652
# [  3.   4.   3.   6.   4.   7.  13.  20.  29.  28.  32.  46.  64.  69.
#  109. 104. 109. 162. 168. 203. 213. 216. 211. 259. 292. 255. 249. 268.
#  246. 196. 217. 195. 177. 141. 124. 116. 110.  77.  76.  38.  44.  35.
#   11.  14.  10.   6.   9.   4.   4.   4.]
# [ 50.01303133  53.92071187  57.82839241  61.73607295  65.64375349
#   69.55143403  73.45911457  77.36679511  81.27447566  85.1821562
#   89.08983674  92.99751728  96.90519782 100.81287836 104.7205589
#  108.62823944 112.53591999 116.44360053 120.35128107 124.25896161
#  128.16664215 132.07432269 135.98200323 139.88968377 143.79736431
#  147.70504486 151.6127254  155.52040594 159.42808648 163.33576702
#  167.24344756 171.1511281  175.05880864 178.96648919 182.87416973
#  186.78185027 190.68953081 194.59721135 198.50489189 202.41257243
#  206.32025297 210.22793352 214.13561406 218.0432946  221.95097514
#  225.85865568 229.76633622 233.67401676 237.5816973  241.48937784
#  245.39705839]

# %% [markdown]
# **TASK 4**: Now draw the pdf for random samples from Task 2.

# %%
#SOLUTION 4:

from scipy.stats import norm

pdf=[]
for i in bins: #bins is generated from the pmf before
    f=norm.pdf(i,mean,sd)
    pdf.append(f)

plt.plot(bins,pdf, linewidth=2, color='brown')

plt.xlabel('Data')
plt.ylabel('Probability')
plt.title('Pdf with mean=150, standard deviation=30')
plt.grid(True)
plt.show()

# %% [markdown]
# **TASK 5**: Now draw the cdf for random samples from Task 2.

# %%
#SOLUTION 5:

cdf=[norm.cdf(i,mean,sd) for i in bins]

plt.plot(bins,cdf, linewidth=2, color='blue')    

plt.xlabel('Data')
plt.ylabel('Probability')
plt.title('Cdf with mean=150, standard deviation=30')
plt.grid(True)
plt.show()

# %% [markdown]
# **TASK 6**:
#
# If mean of a given data for a random value is 81.1 and standard deviation is 4.7, then find the probability of getting a value more than 83.

# %%
#SOLUTION 6:

mean=81.1
sd=4.7

#cdf for less than 83
p=norm.cdf(83, mean, sd)
print(p)

#cdf for more than 83
print (1-p)
# Out:
# 0.6569875109152477
# 0.34301248908475235

# %% [markdown]
# **TASK 7**: The average speed of a car is 65 km/h with a standard deviation of 4. Find the probability that the speed is less than 60 km/h.

# %%
mean = 65
std = 4

print(norm.cdf(60,mean,std))
# Out:
# 0.10564977366685535

# %% [markdown]
# **Task 8**: The average score of a statistics test for a class is 85 and standard deviation is 10. Find the probability of a random score falling between 75 and 95.

# %%
mean = 85
std = 10

print(norm.cdf(95,mean,std)-norm.cdf(75,mean,std))
# Out:
# 0.6826894921370859

# %% [markdown]
# **Task 9**: The heights of students in a class are normally distributed with mean 160cm and standard deviation 8cm. Given that we are looking for students who are larger than 25% of all other students, what size does the subject have to be?

# %%
mean = 160
std = 8

print(norm.ppf(0.25,160,8))
# Out:
# 154.60408199843135

# %% [markdown]
# **Task 10**: The weight of students in a class are normally distributed with mean 45kg and standard deviation 2kg. Given that we are looking for students who are lighter than 95% of all other students, what size does the subject have to be?

# %%
#SOLUTION 10:

mean=45
sd=2

weight=norm.ppf(1-0.95, mean, sd)
print(weight)
# Out:
# 41.71029274609705

# %% [markdown]
# ## Other tasks

# %% [markdown]
# **Task 1**: Generate a random samples for normal distributions with the following properties:
# <br>a) size of samples=1000
# <br>b) mean=8
# <br>c) standard deviation=15

# %%
import numpy as np

n = 1000
mean = 8
std = 15

k = np.random.normal(8,15,1000)
print(k)
sum(k)/len(k)
# Out:
# [ 2.91723783e+01 -3.73664459e+00  1.46785650e+01 -1.05773162e+01
#  -1.74364406e+00  1.82895588e+01  1.00328875e+01  1.02298798e+01
#   2.50944451e+01  6.53607474e-01  1.61037401e+01  2.86183007e+00
#   6.39669147e+00  6.66302322e+00  8.24096551e+00  2.52193571e+00
#   3.56454447e+00  1.05526784e+01  2.49072696e+01  1.64255466e+01
#   8.92659345e+00 -2.19820582e+01  7.31579642e+00 -5.95157976e+00
#   4.03756793e+01  2.49057253e+01  3.43261039e+01  4.20872350e+01
#   3.95332818e+01  2.02191350e+01 -1.23045015e+01 -2.13087849e+00
#   5.03206663e+00 -1.07631974e+01 -1.57075926e+01  1.51424757e+01
#   1.74829860e+01 -5.29900194e+00  1.63418813e+01 -1.44146554e+01
#   2.13695401e+01  3.10534171e+01 -2.82034892e+01 -7.61412308e+00
#   2.63174923e+01  7.23058396e+00  1.19212313e+01  2.56123819e+01
#   1.54691996e+01  4.03149392e+01  9.13798817e+00  4.65887082e+00
#   9.54009416e+00  1.50920552e+01 -1.27117086e+01  1.18918893e+01
#   8.32325435e+00 -4.53331520e-01 -9.17036911e-01  4.01557626e+00
#  -1.19775420e+01  9.81097270e+00  2.30850802e+01  2.01965924e+01
#  -1.71674537e+01 -2.08375813e+01  3.23021645e+00  2.12040194e+01
#   1.84677627e+01  1.29691324e+01  6.68414059e+00  4.05196880e+00
#   2.39255068e+01  3.28025860e+01  1.18634156e+01 -5.19578416e+00
#   1.47524731e+01 -1.44800104e+00  3.16596760e+01  6.44027913e+00
#  -2.07673814e+01  4.01832993e+00  1.80539909e+01  6.45756313e+00
#   4.84124263e+01  3.74312768e+01  5.62542293e+00 -1.44230564e+01
#  -8.73142047e+00 -9.15780155e+00  1.85855342e+01  1.62101089e+01
#   7.27106620e+00 -7.35487752e+00  6.84311800e+00 -7.41077780e+00
#   1.25119414e+01  1.00185616e+01  3.66823043e+01 -8.36473742e-01
#   2.53624487e+01  1.07448440e+01  5.86362617e+00  2.80445754e+01
#  -1.98486940e+01  1.17671801e+00  2.34332791e+01 -1.57438432e+01
#   2.65387575e+01 -2.94289634e+00  3.06364547e+01  3.95266726e+01
#  -8.43929582e+00  2.66124599e+00  1.99896238e+01  1.15712073e+01
#   7.07565562e+00 -5.82047182e+00 -7.51561755e+00  3.96307887e+01
#   1.35406638e+01  4.29241570e-01  2.15425047e+01  2.31292769e+01
#   1.89708088e+01  1.83255715e+01  1.71603495e+01  1.83998313e+01
#   1.11928905e+01  2.84993947e+01 -4.46088620e+00  3.19214763e+01
#   1.70032171e+01  7.87107040e+00 -8.63158048e+00 -2.63230465e+01
#  -1.65456308e+01  1.86719642e+01  2.39385038e+00  9.56555499e+00
#   9.79624349e+00 -2.31922155e+01  1.75914270e+00  1.75373098e+01
#   6.87534721e+00  2.32057385e+00  1.28297017e+01 -1.52952949e+00
#   1.52888625e+01  1.69518255e+00  1.38868231e+01  3.01998062e+01
#   3.79082125e-01  2.65925173e+01  2.17000501e+01  3.33574568e+01
#   1.01260515e+01  1.21525377e+01 -3.49631404e+00 -8.66458775e+00
#  -6.33730343e+00 -2.80969090e+01  2.63211499e+00  3.82306970e+00
#   3.43454545e+00  8.89572894e+00  7.81491338e+00  1.47059311e+01
#   6.92373457e-01  3.07027596e+01  1.01721402e+01  2.40106204e+01
#  -1.30480966e+01 -1.19825629e+01  9.71738948e+00 -5.64341924e+00
#   1.98014657e+01 -5.13407100e+00  2.43796516e+01 -8.29459503e+00
#   1.83076346e+01  2.84989120e+01  1.98178053e+01  1.43509830e-01
#   8.45460442e+00  7.75661116e+00  2.35332714e+01  2.33241964e+01
#  -1.37263050e+01  3.01660535e+01 -4.93969744e+00  2.78273066e+01
#   2.34078539e+01  4.21000079e+00  6.24943510e+00  9.28511383e+00
#   7.97763313e+00  1.26443944e+00  8.59900295e-02  8.61529731e+00
#   1.07124677e+01  1.94378753e+01 -7.42168490e+00  1.68525894e+00
#   1.53174331e+01  1.74878737e+01  1.93776865e+01  8.08985744e+00
#   2.41826648e+01  7.25087713e+00  4.75882481e+01 -3.09076337e+00
#  -3.15142785e+00  2.20180377e+01  9.62044933e+00  3.66127297e+00
#  -1.38825144e+01  3.69540193e+01  3.90980645e+00 -1.96752855e+00
#   1.19340358e+01  5.39655586e-01 -2.37210649e+01 -1.20351060e+01
#  -3.18730275e+01  2.21446719e+01  3.89332745e+00  1.18737207e+01
#   1.80368105e+01  1.82800797e+00 -3.22545811e+01 -8.75222077e+00
#   2.05545487e+01  1.47682266e+01  1.03318818e+01 -1.57024553e+01
#   1.24296638e+01  1.90450507e+00 -8.69939443e+00 -7.53871364e-01
#   1.56234231e+01  1.47208495e+01 -1.18914789e+00  1.98511306e+01
#   2.75787495e+01  3.92536153e+01 -1.44238715e+01  2.29483428e+01
#  -1.39671524e+00  3.25741462e+01  1.43366784e+01 -7.51686017e+00
#   4.79427064e+00  2.78383914e+00  1.75360954e+01 -3.15603338e+00
#   1.22247510e+01 -5.18487928e+00  6.72318384e+00  3.52484267e+01
#  -2.82305512e+00  1.15666389e+01  2.45300377e+01  9.02238059e+00
#   1.40425001e+01 -5.52982986e+00  2.75794946e+01  8.11605468e+00
#   1.00083317e+01  4.88580187e+00 -1.11111066e+01  1.40978158e+01
#   1.30470423e+01  9.30909276e+00 -1.33120084e+01  6.42709505e+00
#   1.15057325e+01  2.23062869e+00 -2.48430536e+01  2.12206060e+01
#   3.50471139e+01 -1.63936909e+00  2.47603675e+01 -9.51711971e+00
#   4.31402349e+00 -3.49113974e+00  2.52401628e+01  2.69406621e+01
#   3.66489384e+00  1.47529788e+01  1.33816435e+01  1.75470501e+01
#   8.47656916e+00  4.96276682e+00  1.57527146e+00  1.76215726e+01
#   1.48890847e+01  8.37255739e+00  2.72276798e+01  3.07171773e+01
#  -4.69320532e+00 -1.43502202e+00 -2.90767365e+00 -3.44284435e+00
#   4.49490142e+01 -3.99427438e+00  9.55988326e+00  1.63525392e+01
#  -1.84293603e+01  1.95076743e+01  2.04283623e+01  4.10384031e+01
#   4.81497541e+01  9.63617101e+00  4.30993765e+01  5.80242058e+00
#   3.36362812e+01 -1.37936235e+01  2.11583242e+01  2.17635364e-02
#   1.97191841e+01  3.11265483e+01 -6.36254127e-02  1.18146834e+01
#   1.34374663e+01 -3.86974061e+01  2.43359671e+01  1.07196310e+01
#   7.27107159e+00  3.12341878e+00 -1.29415306e+01  2.10107073e+01
#   1.29613362e+01  2.87043643e+01  2.66020199e+01  2.63590114e+01
#   1.21485465e+01 -2.95380726e+01 -6.42364488e+00  1.46898880e+00
#   1.16080846e+01  1.72719083e+01  5.97753606e-01 -5.03944580e+00
#   1.81800630e+01  6.71229303e+00  2.05918595e+01  1.37755781e+01
#   1.26811280e+01  1.17187119e+01  7.81209680e-01  2.14190780e+01
#   6.95446485e+00  1.73883420e+01  1.57359628e+01  1.67963568e+00
#  -4.11173925e+00  3.18707136e+00  2.07794323e+01 -2.20254489e+00
#  -1.72196630e+01  6.62666219e-01  2.23329039e+01  2.43871610e+00
#   4.56050996e-01  1.07423624e+01  9.44336283e+00  7.09459686e+00
#  -1.04494345e+01  9.23475332e+00 -1.75125479e+00  3.85717079e+00
#  -3.64807242e-01  1.70795745e+01  3.40279620e+01  4.09316683e+01
#   3.10586963e+01  2.29070584e+01  1.13567968e+01 -2.18708182e+00
#  -1.88741236e+01 -8.27421512e+00  4.59003016e+01 -6.75119750e-01
#  -1.39810474e+01  1.40902309e+01 -7.95720215e+00 -1.45751264e+01
#   7.53305269e+00  7.25644485e+00  7.62721278e-01 -4.34882245e+00
#   7.95984021e-01 -2.76754405e+00  4.03188269e-01  2.40955438e+00
#   2.56063043e+01  1.83457960e+01  1.63941273e+01  9.32179373e+00
#  -1.50693633e+01  3.34905735e+01  2.15280558e+01  2.98864002e+00
#   1.26884789e+01  1.53701822e+01  1.04977123e+01  1.53377739e+00
#   2.00880921e+01  5.38613880e+00  2.54048969e+01 -1.66053185e+00
#   1.92693778e+00  5.07202537e+00  2.15872659e+01  1.42868532e+01
#   1.29124415e+01  1.25833917e+01  1.25483896e+01  2.40731212e+01
#   1.73064537e+01  3.16350538e+01 -2.44645682e+01 -1.23065558e+01
#  -1.72503540e+00 -1.65613495e+01  1.97336536e+00 -2.80306829e+00
#   8.51262236e+00 -2.12963454e+01  1.54512819e+01 -1.71323354e+01
#   5.27650175e+00  3.39461912e+01  3.98934122e+01  7.34971357e+00
#   5.08998540e+00  5.96774818e+00 -2.47410070e+00 -2.99020045e+01
#   4.02739336e+01  1.15124685e+01  8.86279353e+00 -3.89474122e-01
#  -8.62440553e+00 -4.82646421e+00  3.52356980e+01  1.11415580e+01
#  -1.97402125e+01  8.40664108e+00  2.18453034e+00 -7.27858318e+00
#   1.19146664e+01 -1.11709936e+01 -9.57903979e+00  2.42207050e+01
#  -4.85387939e+00  2.36224074e+01 -2.27098612e+01  4.01800008e+01
#  -1.77571993e+00  6.28538192e+00 -1.83975130e+01 -1.57762219e+00
#   3.10449391e+01 -1.51581197e+01  1.13230547e+01  1.48856118e+01
#  -1.90859645e+01  3.63900691e+00  1.97314212e+01 -1.38290975e+01
#   1.79458523e+01 -7.48801681e+00  2.32053496e+01 -8.56569811e+00
#   2.91124214e+01  1.69549815e+00  1.37942815e+01  2.23585551e+01
#  -1.34190325e+01  1.98465029e+01 -1.34224079e+01  6.67539482e+00
#   1.63417153e+01  2.83901914e+01  2.57034386e+01  9.14219600e+00
#  -1.58633909e+01  1.45064454e+01  1.47405382e+01  1.39054975e+01
#  -1.24046060e+01  5.69099546e+00  2.25911442e+01  2.13711240e+00
#   2.62705025e+01 -9.78754068e+00  2.27332744e+01  2.25220858e+01
#   7.85046566e+00  3.85415533e+01  1.55202087e+01  2.92574573e+01
#   2.41323467e+01  1.36610595e+01 -2.22437457e+00  1.86164763e+01
#  -7.33036625e+00 -1.25614413e+01  1.07119585e+01  3.89473162e+01
#   9.89134872e-01  2.50605691e+01  1.25352071e+01  1.61710815e+01
#  -4.63142357e+00  2.46832721e+01 -1.24272701e+01  4.46777986e+00
#   1.68732879e+01 -2.51844695e-02  4.05895992e+00  1.81758956e+01
#   2.80345460e+01 -2.75426619e+00 -1.13456238e+01  1.59680604e+01
#   1.44211737e+01  1.47629839e+01  8.96518261e+00 -2.96717206e+00
#   8.24961206e+00  3.08493379e+00 -2.67459391e+01  1.48576189e+01
#  -2.81848820e+00 -1.19737298e+00  2.88910415e+01  2.70072921e+00
#   2.28656374e+01  2.71045626e+01  1.76336260e+01  1.20787148e+00
#  -1.20575569e+01  2.64105082e+01  8.24639160e+00 -1.06145663e+01
#  -1.29210606e+00 -4.21517466e-01 -3.33841118e+01  5.74171286e+00
#   4.06714989e+00 -8.68472045e+00  2.15762865e+01  9.79879460e+00
#   3.68721504e+00  4.31338688e+01  1.73111566e+01  2.33946009e+01
#  -2.99323418e-01  1.68571688e+01 -6.35609056e+00  5.42029186e+00
#   1.02133924e+01  1.14025140e+01  2.51939812e+01  3.10599770e+01
#   3.60594631e+01  1.88595380e+01  1.00565340e+01  1.20389834e+01
#   2.58852729e+01  1.34554933e+01  1.43018858e+01 -6.71065965e+00
#  -1.18341917e+00  1.84073352e+01 -7.33281938e-01 -1.56790161e+01
#  -6.34319941e+00 -1.95593937e+00  3.36131195e+00 -1.05753093e+01
#   3.25071612e+01 -2.73211356e+00  3.15401746e+00  2.29912524e+01
#   1.70022997e+00  2.32162648e+01 -4.05265058e+00  1.64814622e+00
#   2.58696943e+01  1.06993383e+01  1.64752608e+00  3.10364767e+01
#   1.89185869e+01  3.51824029e+01  3.66367892e+00  1.65881414e+01
#   2.62662615e+01  3.31656941e+01  2.44476737e+01  1.23221885e+00
#   1.21055378e+01  1.76063575e+01  3.06536179e+01  3.01118412e+01
#   3.17430110e+00 -8.47537617e+00  2.42610924e+01  3.25566626e+00
#   7.41485924e+00 -3.72281849e+00 -2.11614633e+00  1.19735654e+01
#   2.69074572e+01  1.97109096e+01  1.35420130e+01  1.82681152e+01
#  -1.10364077e+00 -6.50261816e+00  4.49910202e+01 -1.58383013e+01
#  -5.52312620e+00 -3.96568764e+00  2.11139039e+01  4.62385199e+00
#  -8.24533012e+00  1.25761167e+01  1.92016140e+01  1.85352746e+01
#  -5.00241448e+00  2.45022331e+01  1.93040569e+01  1.50495950e+01
#   2.68987405e+01 -1.27868520e+01  1.72884685e+01 -3.32106889e+00
#   2.01829146e-02  1.11106665e+01 -1.34622418e+01  1.07563737e+01
#   5.37112567e+00 -1.41754906e+01 -4.76905956e+01 -2.70519892e+01
#  -1.27745859e+00  5.55484987e+00  1.50831179e+01  8.32894035e+00
#   2.81901417e+01  7.59755493e+00  2.13045789e+01 -1.17166545e+01
#  -6.34078609e+00  1.06019489e+01  4.40790920e+01  4.46583373e+00
#  -4.34886573e+00 -1.30193189e+01  2.46967240e-02  1.72081408e+01
#  -6.93935572e+00 -4.84425910e+00  1.19034707e+01  2.08659571e+01
#   3.05111094e+01  1.36242123e+01  4.52191246e+00  2.02069519e+01
#   1.11971165e+01  3.71366970e+00  1.59633767e+01 -1.78427271e+01
#  -4.82261287e+00  4.88340328e+00  2.80653368e+01  1.67158778e+01
#   7.51059058e+00  4.56885712e+01  1.34188610e+01 -1.32441787e+01
#  -3.96391343e-01 -3.97304931e+00  2.43710005e+01  2.64933201e+01
#   1.99232351e+01  2.69947838e+00 -2.10392511e+01  1.43554420e+01
#   2.79538144e+01 -3.69925290e+00  1.94892491e+01 -2.13847390e+00
#   2.46283497e+01  3.10361843e+01 -3.57427024e+00  1.00613100e+01
#   2.32391380e+01  1.25523707e+01 -1.67742242e+01  3.07528865e+01
#   2.63347634e+01  2.22500439e+01 -1.44392895e+01 -7.60257245e-02
#  -2.86854929e+01 -3.47109160e+00  5.83812370e+00  6.95008144e+00
#   2.54386566e+01  3.13358526e+01  8.87091251e+00  2.81357146e+01
#  -1.19400999e+01 -8.11787631e-01 -2.46604713e+00  9.30667035e+00
#   1.33690195e+01 -1.04968118e+01  5.38864366e+00  4.00530937e+01
#   5.08675582e+00  3.47431179e+00  2.85386732e+01  1.43056269e+01
#   7.15678226e+00  9.40907603e+00  2.35895338e+01 -1.44678181e+01
#  -8.66582458e+00  8.84190560e+00 -6.59300756e+00  1.11028801e+01
#   2.65307617e+00 -1.47618100e+01  3.23796610e+01  1.67112563e+01
#   1.32818374e-01  6.06935349e+00  1.47173294e+01  3.78258263e+00
#   6.95608093e-01  2.60526243e+00  1.73818803e+01  4.05720239e-01
#  -3.56273882e+00  1.76222057e+00  1.76977766e+01  1.22464631e+01
#   2.11165549e+01  9.74550105e+00  3.40664247e+01  8.87300278e+00
#   1.68612979e+01  1.20510370e+01 -9.06616021e+00  4.54311848e+00
#   3.87473334e+00 -1.42612959e+01  1.34319154e+01  1.03239065e+01
#  -5.73848674e-01 -2.95328174e+00 -1.57574962e+01  7.37895374e+00
#   1.13864109e+01 -1.28960834e+01 -1.00897824e+00  1.53723695e+01
#   1.84952948e+01 -6.78293783e+00  8.71630625e+00  3.04148798e+01
#   3.13902122e+01  1.21913023e+01  2.10827768e+01  1.57799689e+01
#   3.34332458e+01  8.49534129e+00 -9.43695074e-01 -8.34699741e+00
#   2.38403960e+01  7.26448117e+00 -2.54888822e+01  1.06660352e+01
#   2.52694177e+01  1.61667437e+00 -4.61839122e+00  4.60304688e-01
#   1.85983237e+01  1.29779270e+01  6.82939344e+00 -1.36501948e+01
#   2.54258415e+01 -1.18872486e+00 -7.87136206e-01 -1.06216277e+01
#   8.31799509e+00  8.91860469e+00 -7.72986326e-01  2.26179037e+01
#   5.85697478e+00 -9.13311508e+00  2.11116048e+00 -5.16555906e-02
#  -5.68007744e+00  2.48707821e+01  1.43504879e+01  6.45877636e+00
#   1.26349361e+01  2.07939232e+01  9.55994534e+00  1.83089922e+00
#   2.59639967e+00 -6.12026886e+00  6.66936675e+00  2.51348746e+01
#   2.95015668e+01 -2.38881054e+00  1.07438942e+01  1.71393347e+01
#  -1.27847206e+01  4.77788699e+01  9.66066650e+00 -1.28800114e-03
#  -6.57398671e+00 -5.58569172e+00 -2.50495879e+00  2.08516129e+01
#   6.36684690e+00 -6.73775767e+00  4.16496632e+00  1.65240574e+00
#   1.73152518e+01  1.14390509e+01 -1.48148608e+01  2.15833085e+01
#   2.19714015e+01  7.01504887e+00  1.73656167e+01  3.39756505e+00
#   4.04542146e+00 -1.58610572e+01  1.22380365e+00  7.73791152e+00
#  -3.25871480e-01  3.24532851e+01  4.42514130e+00  2.44609416e+01
#   1.55879615e+01  5.31425843e+00  1.43488324e+01  2.62526552e+01
#   1.65438241e+01  6.75860808e+00  1.56696396e+01  1.84553425e+00
#   1.41082178e+01  6.51573378e+00  2.44310794e+01 -2.89545648e+00
#  -1.75533832e+00  2.57815776e+01  2.36586802e+01  5.53605246e+00
#   4.47071785e+00  4.77939514e+00  3.00053762e+01 -9.38150374e+00
#   1.81769202e+00  2.42768357e+01  8.77857051e-01  9.70791707e+00
#   1.76822126e+01  4.03118876e+00 -3.61063915e+00  1.94523296e+00
#   1.18863743e+01  3.30460491e+01  1.23396811e+01  5.99537719e+00
#   5.33266594e+00  5.55858819e+00  1.16541653e+01  1.44185148e+01
#   4.34391681e+00  2.52789769e+00 -1.75106628e+01  6.79715665e+00
#   1.37336633e+01 -1.54142456e+01  2.81348455e+01 -7.60695380e+00
#  -2.19973609e+01  3.17147694e+01  3.49605114e+01  3.14591209e+00
#   9.76640760e+00 -6.08756409e+00  1.52173941e+01 -4.34018880e+00
#   1.71243358e+01  4.88619524e+00  2.17412444e+01  2.38158455e+01
#   2.17530501e+01  6.54219419e-01 -1.45935354e+01  2.51948026e+01
#  -1.51420210e+00 -2.60378003e+01  7.84660013e+00  5.93414672e+00
#   2.66911562e+01 -1.00361338e+01  1.49211766e+01  1.83256241e+01
#   5.98568297e+00  6.60842882e+00  1.95279311e+01  1.61713578e+00
#   1.23097296e+01  1.14140150e+01  2.22837243e+01  1.28714812e+01
#   1.90459150e+00  2.37508589e+00  6.76630324e+00  1.11144207e+01
#   1.12270026e+01 -8.07211847e+00 -5.23336110e+00 -2.62112940e+01
#   1.40860731e+00  3.12821822e+01  2.16159432e+00  1.75561458e+00
#  -2.19100291e+01 -1.06588133e+01  6.96752720e+00 -6.95907608e+00
#   1.26297968e+01 -1.40929130e+01  4.09628115e+01  9.09406178e+00
#  -1.80559552e+01 -1.36071547e+01  1.24295903e+01 -3.15808837e+01
#  -3.83816735e+00  1.49604723e+01  2.88477808e+01  6.76283576e+00
#   3.53432822e+00  2.35467165e+01  2.83307249e+01  1.55518801e+01
#   5.61264555e+00  1.77515255e+01 -2.62016232e+00  2.20757957e+01
#   1.00495382e+01  1.43387913e+01  1.04509594e+01  2.11299666e+01
#   3.88490038e+00  8.65844325e+00 -6.38655831e+00 -4.18906578e+01
#   1.85866383e+00  3.98532305e+01  8.12196665e-01  4.20226401e+01
#  -1.06073245e+01 -1.93060184e+00 -2.10886199e+00 -6.37685414e+00
#   3.33476777e+01  2.51369537e+01 -1.03402697e+01  2.25358259e+01
#   1.11600527e+01 -1.46328025e+01  9.26963707e+00  4.05790312e+01
#   1.10382667e+01 -7.95471961e+00 -7.55229140e+00 -7.75668906e+00
#   7.62847429e+00  1.83064560e+01  3.41899539e+01  3.22662540e+01
#  -2.38934035e+01  1.56351475e+01 -1.32581120e-01  2.68503577e+01]
# 8.381975043330023

# %% [markdown]
# **Task 2**: Generate a random samples for normal distributions with the following properties:
# <br>a) size of samples=100
# <br>b) mean=50
# <br>c) standard deviation=10

# %%
n =100
mean= 50
std = 10

p = np.random.normal(50,10,100)
print(p)
sum(p)/len(p)
# Out:
# [58.24902779 40.66398423 40.50265837 47.51760881 49.41109231 48.62126097
#  62.63945427 48.45913418 76.10698329 61.99225641 40.44882806 44.34633096
#  54.04165614 56.00624019 48.85789107 58.03604329 46.52312518 42.26703047
#  61.83411681 75.80931796 52.58465961 55.17116531 43.92591626 54.69943282
#  48.45257929 42.38043868 52.08775769 49.38863557 60.34938981 50.19733431
#  55.43977424 59.99090219 45.75836715 59.16548316 74.34378993 43.04401749
#  48.17898511 48.17406187 54.42920259 57.55308447 57.35949689 40.74758864
#  55.88458874 47.72814286 59.47912041 46.71294406 53.62040909 51.57214465
#  48.0558384  44.22128747 49.49146339 60.59714508 38.15473417 60.10981549
#  69.60539467 47.85359324 68.44242922 63.06944852 53.70376906 60.57992539
#  42.57142203 54.25540435 50.75032351 49.76339333 46.76894673 55.78220424
#  52.66009969 43.15539217 51.7527078  50.41038734 52.18192282 70.74633138
#  49.95224729 45.82000716 46.94489329 52.40170424 43.40492661 49.2240837
#  38.64561971 49.80243687 44.76512275 54.83739427 36.43710791 43.12191642
#  56.52235324 68.96464538 63.44617013 63.20728751 64.03594687 66.95944233
#  48.44196151 43.62561016 62.49493719 49.50844386 41.12643207 45.01585779
#  39.75707916 49.29313021 46.6910264  53.86031555]
# 52.33744932691982

# %% [markdown]
# **Task 3**: Using the same result from task 1 and task 2, draw a graph for its probability density function

# %%
# from result 1
import matplotlib.pyplot as plt
import scipy.stats as st

k.sort()
pdf_k = st.norm.pdf(k,loc = 8, scale = 15)
plt.plot(k,pdf_k)

# %%
# from result 2
p.sort()
pdf_p = st.norm.pdf(p,loc = 50, scale = 10)
plt.plot(p,pdf_p)
